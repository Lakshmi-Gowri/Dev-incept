# %% [markdown]
# ### Loading libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **load data**

# %%
df=pd.read_csv("C:\\Users\\LAKSHMI\\Desktop\\Automobile (1).csv")

# %% [markdown]
# **How to print the first 5/10 rows in the data?**

# %%
df.head(5)
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %% [markdown]
# **to print last rows of the data**

# %%
df.tail()
# Out:
#      symboling  normalized_losses   make fuel_type aspiration number_of_doors  \
# 196         -1                 95  volvo       gas        std            four
# 197         -1                 95  volvo       gas      turbo            four
# 198         -1                 95  volvo       gas        std            four
# 199         -1                 95  volvo    diesel      turbo            four
# 200         -1                 95  volvo       gas      turbo            four
#
#     body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# 196      sedan          rwd           front       109.1  ...          141
# 197      sedan          rwd           front       109.1  ...          141
# 198      sedan          rwd           front       109.1  ...          173
# 199      sedan          rwd           front       109.1  ...          145
# 200      sedan          rwd           front       109.1  ...          141
#
# ...

# %% [markdown]
# Pandas Series is a one-dimensional labeled array capable of holding data of any type (integer, string, float, python objects, etc.). The axis labels are collectively called index.<br> **Series() is used to get the single column data.**

# %%
ser=pd.Series(df['fuel_type'])
print(ser)
# Out:
# 0         gas
# 1         gas
# 2         gas
# 3         gas
# 4         gas
#         ...
# 196       gas
# 197       gas
# 198       gas
# 199    diesel
# 200       gas
# Name: fuel_type, Length: 201, dtype: object

# %% [markdown]
# **to know the column datatypes**

# %%
df.dtypes
# Out:
# symboling                int64
# normalized_losses        int64
# make                    object
# fuel_type               object
# aspiration              object
# number_of_doors         object
# body_style              object
# drive_wheels            object
# engine_location         object
# wheel_base             float64
# length                 float64
# width                  float64
# height                 float64
# curb_weight              int64
# engine_type             object
# number_of_cylinders     object
# engine_size              int64
# fuel_system             object
# bore                   float64
# stroke                 float64
# compression_ratio      float64
# horsepower               int64
# peak_rpm                 int64
# city_mpg                 int64
# highway_mpg              int64
# price                    int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 26 columns):
# symboling              201 non-null int64
# normalized_losses      201 non-null int64
# make                   201 non-null object
# fuel_type              201 non-null object
# aspiration             201 non-null object
# number_of_doors        201 non-null object
# body_style             201 non-null object
# drive_wheels           201 non-null object
# engine_location        201 non-null object
# wheel_base             201 non-null float64
# length                 201 non-null float64
# width                  201 non-null float64
# height                 201 non-null float64
# curb_weight            201 non-null int64
# engine_type            201 non-null object
# number_of_cylinders    201 non-null object
# engine_size            201 non-null int64
# fuel_system            201 non-null object
# bore                   201 non-null float64
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=201, step=1)

# %%
df.columns
# Out:
# Index(['symboling', 'normalized_losses', 'make', 'fuel_type', 'aspiration',
#        'number_of_doors', 'body_style', 'drive_wheels', 'engine_location',
#        'wheel_base', 'length', 'width', 'height', 'curb_weight', 'engine_type',
#        'number_of_cylinders', 'engine_size', 'fuel_system', 'bore', 'stroke',
#        'compression_ratio', 'horsepower', 'peak_rpm', 'city_mpg',
#        'highway_mpg', 'price'],
#       dtype='object')

# %% [markdown]
# **to_numpy** helps to convert dataframe into numpy array

# %%
df.to_numpy()
# Out:
# array([[3, 168, 'alfa-romero', ..., 21, 27, 13495],
#        [3, 168, 'alfa-romero', ..., 21, 27, 16500],
#        [1, 168, 'alfa-romero', ..., 19, 26, 16500],
#        ...,
#        [-1, 95, 'volvo', ..., 18, 23, 21485],
#        [-1, 95, 'volvo', ..., 26, 27, 22470],
#        [-1, 95, 'volvo', ..., 19, 25, 22625]], dtype=object)

# %% [markdown]
# **describe()** shows the quick statistic summary of the data

# %%
df.describe()
# Out:
#         symboling  normalized_losses  wheel_base      length       width  \
# count  201.000000         201.000000  201.000000  201.000000  201.000000
# mean     0.840796         125.189055   98.797015  174.200995   65.889055
# std      1.254802          33.572966    6.066366   12.322175    2.101471
# min     -2.000000          65.000000   86.600000  141.100000   60.300000
# 25%      0.000000         101.000000   94.500000  166.800000   64.100000
# 50%      1.000000         122.000000   97.000000  173.200000   65.500000
# 75%      2.000000         150.000000  102.400000  183.500000   66.600000
# max      3.000000         256.000000  120.900000  208.100000   72.000000
#
#            height  curb_weight  engine_size        bore      stroke  \
# count  201.000000   201.000000   201.000000  201.000000  201.000000
# mean    53.766667  2555.666667   126.875622    3.329701    3.261741
# std      2.447822   517.296727    41.546834    0.268166    0.317875
# ...

# %% [markdown]
# This method **sort_index** with parameter **axis=1** means sorts column names and **ascending=True** means sorts the rows in ascending order i.e from smaller to larger values.

# %%
df.sort_index(axis=1,ascending=True)
# Out:
#     aspiration   body_style  bore  city_mpg  compression_ratio  curb_weight  \
# 0          std  convertible  3.47        21                9.0         2548
# 1          std  convertible  3.47        21                9.0         2548
# 2          std    hatchback  2.68        19                9.0         2823
# 3          std        sedan  3.19        24               10.0         2337
# 4          std        sedan  3.19        18                8.0         2824
# ..         ...          ...   ...       ...                ...          ...
# 196        std        sedan  3.78        23                9.5         2952
# 197      turbo        sedan  3.78        19                8.7         3049
# 198        std        sedan  3.58        18                8.8         3012
# 199      turbo        sedan  3.01        26               23.0         3217
# 200      turbo        sedan  3.78        19                9.5         3062
#
# ...

# %% [markdown]
# sorts the values in the column from smaller to larger(ascending=true) or larger to smaller(ascending=false)

# %%
df.sort_values('bore',ascending=True)
# Out:
#      symboling  normalized_losses           make fuel_type aspiration  \
# 130          3                150           saab       gas        std
# 2            1                168    alfa-romero       gas        std
# 29           2                137          honda       gas        std
# 30           2                137          honda       gas        std
# 31           1                101          honda       gas        std
# ..         ...                ...            ...       ...        ...
# 72           1                140        mercury       gas      turbo
# 200         -1                 95          volvo       gas      turbo
# 71           1                140  mercedes-benz       gas        std
# 70           0                140  mercedes-benz       gas        std
# 122          3                186        porsche       gas        std
#
#     number_of_doors body_style drive_wheels engine_location  wheel_base  ...  \
# ...

# %% [markdown]
# **selecting single column**

# %%
df['aspiration']
# Out:
# 0        std
# 1        std
# 2        std
# 3        std
# 4        std
#        ...
# 196      std
# 197    turbo
# 198      std
# 199    turbo
# 200    turbo
# Name: aspiration, Length: 201, dtype: object

# %% [markdown]
# **slicing**

# %%
f=df[0:3]

# %%
f
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# 0          130         mpfi  3.47    2.68               9.0        111
# 1          130         mpfi  3.47    2.68               9.0        111
# 2          152         mpfi  2.68    3.47               9.0        154
#
#    peak_rpm city_mpg  highway_mpg  price
# 0      5000       21           27  13495
# ...

# %% [markdown]
# **copy()**

# %%
cp=df.copy()

# %%
cp
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# ...

# %% [markdown]
# **dropping rows**

# %%
df.dropna(how='any')
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# ...

# %%
df.fillna(value=5) #filling Nan values with 5
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# ...
